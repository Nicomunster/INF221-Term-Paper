# %% [markdown]
# # INF221 Term Paper Benchmarking

# %% [markdown]
# ## Sorting algorithm defintions

# %%
import math


def merge(a, first_index, middle_index, last_index):
    n1 = middle_index - first_index + 1
    n2 = last_index - middle_index

    left = [0] * n1
    right = [0] * n2

    for i in range(n1):
        left[i] = a[first_index + i - 1]

    for j in range(n2):
        right[j] = a[middle_index + j]

    left.append(float('inf'))
    right.append(float('inf'))

    i = 0
    j = 0

    for k in range(first_index - 1, last_index):
        if left[i] <= right[j]:
            a[k] = left[i]
            i += 1
        else:
            a[k] = right[j]
            j += 1

    return a


def merge_sort(a, first_index=0, last_index=None):
    """Sorts a list using the 'merge-sort' algorithm."""
    if last_index is None:
        last_index = len(a) - 1
    if first_index < last_index:
        middle_index = (first_index + last_index) // 2
        merge_sort(a, first_index, middle_index)
        merge_sort(a, middle_index + 1, last_index)
        return merge(a, first_index, middle_index, last_index)


def parent(i):
    return math.floor((i-1) / 2)


def left_child(i):
    return 2 * i + 1


def right_child(i):
    return 2 * i + 2


def max_heapify(a, i, heap_size):
    """Max-heapifies subtree of 'a' rooted at 'i'."""
    l = left_child(i)
    r = right_child(i)
    if l <= heap_size - 1 and a[l] > a[i]:
        largest = l
    else:
        largest = i
    if r <= heap_size - 1 and a[r] > a[largest]:
        largest = r
    if largest != i:
        a[i], a[largest] = a[largest], a[i]
        max_heapify(a, largest, heap_size)


def build_max_heap(a):
    """Builds a max heap"""
    heap_size = len(a)
    for i in range(math.floor(heap_size / 2), -1, -1):
        max_heapify(a, i, heap_size)


def heap_sort(a):
    """Sorts a list using the 'heap-sort' algorithm."""

    build_max_heap(a)
    heap_size = len(a)
    for i in range(len(a) - 1, 0, -1):
        a[0], a[i] = a[i], a[0]
        heap_size -= 1
        max_heapify(a, 0, heap_size)


def partition(array, low, high):
    """DEFINE PARTITION FOR QUICKSORT"""
    i = (low - 1)
    pivot = array[high]
    for j in range(low, high):
        if array[j] <= pivot:
            i = i + 1
            array[i], array[j] = array[j], array[i]
    array[i + 1], array[high] = array[high], array[i + 1]
    return i + 1


def quick_sort(array, low=0, high=None):
    """Sorts a list using the quicksort algorithm."""
    if high is None:
        high = len(array) - 1
    if low < high:
        part = partition(array, low, high)
        quick_sort(array, low, part - 1)
        quick_sort(array, part + 1, high)

# %% [markdown]
# ## Benchmarking

# %%
import numpy as np
import timeit
import copy
import pandas as pd
import matplotlib.pyplot as plt


np.random.seed(12235)
results = pd.DataFrame(columns=['Input ordering', 'Input size', 'Run number', 'Sorting algorithm', 'Time'])
sorting_functions = {'Merge sort': merge_sort, 'Heapsort': heap_sort, 'Quicksort': quick_sort, 'Built-in Python': sorted, 'Numpy': np.sort}

for input_ordering in ['sorted', 'reverse', 'random']:
    for input_size in range(1, 9):
        test_data = np.random.random((10**input_size, ))
        if input_ordering == 'sorted':
          test_data = sorted(test_data)
        elif input_ordering == 'reverse':
          test_data = list(reversed(sorted(test_data)))
        
        for sorting_name, sorting_function in sorting_functions.items():
            quicksort_recursion_error = sorting_name == 'Quicksort' and ((input_ordering == 'sorted' or input_ordering == 'reverse') and input_size > 2)
            
            if not quicksort_recursion_error:
                clock = timeit.Timer(stmt='sort_func(copy(data))', globals={'sort_func': sorting_function, 'data': test_data, 'copy': copy.copy})

                n_ar, t_ar = clock.autorange()
                t = [tm / n_ar for tm in clock.repeat(repeat=7, number=n_ar)]
                print(f"{sorting_name} minimum time on {input_ordering} data of size 10^{input_size}:", min(t))
        
                for run_number in range(7):
                    results = results.append({'Input ordering': input_ordering, 'Input size': 10**input_size, 'Run number': run_number + 1, 'Sorting algorithm': sorting_name, 'Time': t[run_number]}, ignore_index=True)
        print("--------------------")

print(results)
results.to_csv('results.csv')
# Out:
# Merge sort minimum time on sorted data of size 10^1: 4.069626000000426e-05
# Heapsort minimum time on sorted data of size 10^1: 3.2583500000009735e-05
# Quicksort minimum time on sorted data of size 10^1: 2.5088000000005195e-05
# Built-in Python minimum time on sorted data of size 10^1: 9.363672000008592e-07
# Numpy minimum time on sorted data of size 10^1: 7.515448000003744e-06
# --------------------
# Merge sort minimum time on sorted data of size 10^2: 0.0005236275999995996
# Heapsort minimum time on sorted data of size 10^2: 0.0006138350000001083
# Quicksort minimum time on sorted data of size 10^2: 0.0014966409999988173
# Built-in Python minimum time on sorted data of size 10^2: 4.388817999997627e-06
# Numpy minimum time on sorted data of size 10^2: 1.8778114999986427e-05
# --------------------
# Merge sort minimum time on sorted data of size 10^3: 0.007103885999995328
# Heapsort minimum time on sorted data of size 10^3: 0.010738960000003317
# Built-in Python minimum time on sorted data of size 10^3: 3.7711399999989225e-05
# Numpy minimum time on sorted data of size 10^3: 0.0001361842499998147
# --------------------
# Merge sort minimum time on sorted data of size 10^4: 0.0891406000000643
# Heapsort minimum time on sorted data of size 10^4: 0.1511587499999223
# Built-in Python minimum time on sorted data of size 10^4: 0.00039588199999980134
# Numpy minimum time on sorted data of size 10^4: 0.0012733470000011948
# --------------------
# Merge sort minimum time on sorted data of size 10^5: 1.1210095000001274
# Heapsort minimum time on sorted data of size 10^5: 1.9957666999998764
# Built-in Python minimum time on sorted data of size 10^5: 0.02284992999998394
# Numpy minimum time on sorted data of size 10^5: 0.0424389799999517
# --------------------
# Merge sort minimum time on sorted data of size 10^6: 13.952365099999952
# Heapsort minimum time on sorted data of size 10^6: 24.61513960000002
# Built-in Python minimum time on sorted data of size 10^6: 0.2760619000000588
# Numpy minimum time on sorted data of size 10^6: 0.4978471000003992
# --------------------
# Merge sort minimum time on sorted data of size 10^7: 180.59526619999997
# Heapsort minimum time on sorted data of size 10^7: 316.7852759999996
# Built-in Python minimum time on sorted data of size 10^7: 4.636193299999832
# Numpy minimum time on sorted data of size 10^7: 7.263480999999956
# --------------------
# Merge sort minimum time on sorted data of size 10^8: 2299.542179600001
# Heapsort minimum time on sorted data of size 10^8: 3362.7228447000016
# Built-in Python minimum time on sorted data of size 10^8: 63.89204500000051
# Numpy minimum time on sorted data of size 10^8: 101.2341688000015
# --------------------
# Merge sort minimum time on reverse data of size 10^1: 4.211951999895973e-05
# Heapsort minimum time on reverse data of size 10^1: 2.5339440000243484e-05
# Quicksort minimum time on reverse data of size 10^1: 2.0060080000257586e-05
# Built-in Python minimum time on reverse data of size 10^1: 9.313340000153403e-07
# Numpy minimum time on reverse data of size 10^1: 7.66057600005297e-06
# --------------------
# Merge sort minimum time on reverse data of size 10^2: 0.0005484667999990051
# Heapsort minimum time on reverse data of size 10^2: 0.0005093957999924896
# Quicksort minimum time on reverse data of size 10^2: 0.0009670424999785609
# Built-in Python minimum time on reverse data of size 10^2: 4.3836600000213366e-06
# Numpy minimum time on reverse data of size 10^2: 1.91236900005606e-05
# --------------------
# Merge sort minimum time on reverse data of size 10^3: 0.007166915999987395
# Heapsort minimum time on reverse data of size 10^3: 0.009066315000018222
# Built-in Python minimum time on reverse data of size 10^3: 3.660906000004616e-05
# Numpy minimum time on reverse data of size 10^3: 0.0001405202999994799
# --------------------
# Merge sort minimum time on reverse data of size 10^4: 0.09020594999674358
# Heapsort minimum time on reverse data of size 10^4: 0.1341031500014651
# Built-in Python minimum time on reverse data of size 10^4: 0.0003873017999867443
# Numpy minimum time on reverse data of size 10^4: 0.001368887499993434
# --------------------
# Merge sort minimum time on reverse data of size 10^5: 1.1843066000001272
# Heapsort minimum time on reverse data of size 10^5: 1.8318794000006164
# Built-in Python minimum time on reverse data of size 10^5: 0.023420400000031805
# Numpy minimum time on reverse data of size 10^5: 0.043514659999345895
# --------------------
# Merge sort minimum time on reverse data of size 10^6: 14.87883540000621
# Heapsort minimum time on reverse data of size 10^6: 23.429291500004183
# Built-in Python minimum time on reverse data of size 10^6: 0.2823738000006415
# Numpy minimum time on reverse data of size 10^6: 0.5084901000009268
# --------------------
# Merge sort minimum time on reverse data of size 10^7: 201.81014770000183
# Heapsort minimum time on reverse data of size 10^7: 280.8510066000017
# Built-in Python minimum time on reverse data of size 10^7: 4.199503600000753
# Numpy minimum time on reverse data of size 10^7: 7.145887500002573
# --------------------
# Merge sort minimum time on reverse data of size 10^8: 2655.4689278000005
# Heapsort minimum time on reverse data of size 10^8: 3296.6189845000044
# Built-in Python minimum time on reverse data of size 10^8: 72.6328732999973
# Numpy minimum time on reverse data of size 10^8: 124.91960779999499
# --------------------
# Merge sort minimum time on random data of size 10^1: 5.797209999873303e-05
# Heapsort minimum time on random data of size 10^1: 5.550409999850672e-05
# Quicksort minimum time on random data of size 10^1: 3.467032000189647e-05
# Built-in Python minimum time on random data of size 10^1: 5.4082359999301845e-06
# Numpy minimum time on random data of size 10^1: 5.709744000050705e-06
# --------------------
# Merge sort minimum time on random data of size 10^2: 0.0007175639999913983
# Heapsort minimum time on random data of size 10^2: 0.001081003500003135
# Quicksort minimum time on random data of size 10^2: 0.0004708127999911085
# Built-in Python minimum time on random data of size 10^2: 3.738181999942754e-05
# Numpy minimum time on random data of size 10^2: 8.163459999777841e-06
# --------------------
# Merge sort minimum time on random data of size 10^3: 0.009543937999987975
# Heapsort minimum time on random data of size 10^3: 0.017663834999984827
# Quicksort minimum time on random data of size 10^3: 0.006944692000106442
# Built-in Python minimum time on random data of size 10^3: 0.0004402613999845926
# Numpy minimum time on random data of size 10^3: 5.0601459998870265e-05
# --------------------
# Merge sort minimum time on random data of size 10^4: 0.11715275000460679
# Heapsort minimum time on random data of size 10^4: 0.24979739999980666
# Quicksort minimum time on random data of size 10^4: 0.166392300001462
# Built-in Python minimum time on random data of size 10^4: 0.005987843999755569
# Numpy minimum time on random data of size 10^4: 0.0011168718000117224
# --------------------
# Merge sort minimum time on random data of size 10^5: 1.4327576000068802
# Heapsort minimum time on random data of size 10^5: 3.203969499998493
# Quicksort minimum time on random data of size 10^5: 1.1200217000005068
# Built-in Python minimum time on random data of size 10^5: 0.1008442499951343
# Numpy minimum time on random data of size 10^5: 0.014908090000244557
# --------------------
# Merge sort minimum time on random data of size 10^6: 16.237003099988215
# Heapsort minimum time on random data of size 10^6: 40.77560090000043
# Quicksort minimum time on random data of size 10^6: 14.276377699992736
# Built-in Python minimum time on random data of size 10^6: 1.6411329999973532
# Numpy minimum time on random data of size 10^6: 0.14546844999858877
# --------------------
# Merge sort minimum time on random data of size 10^7: 214.3247796999931
# Heapsort minimum time on random data of size 10^7: 489.5995913000079
# Quicksort minimum time on random data of size 10^7: 168.2846159000037
# Built-in Python minimum time on random data of size 10^7: 21.812129700003425
# Numpy minimum time on random data of size 10^7: 1.840899700007867
# --------------------
# Merge sort minimum time on random data of size 10^8: 2071.8569707999995

# %% [markdown]
# ## Plotting by input data

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

results = pd.read_csv('results.csv')
input_sizes = [10**1, 10**2, 10**3, 10**4, 10**5, 10**6, 10**7]

for input_ord in ['sorted', 'reverse', 'random']:
    plt.figure()
    is_input_ord = results['Input ordering'] == input_ord
    results_input_ord = results[is_input_ord]

    for sorting_algorithm in ['Merge sort', 'Heapsort', 'Quicksort', 'Built-in Python', 'Numpy']:
        is_sorting_algorithm = results_input_ord['Sorting algorithm'] == sorting_algorithm
        results_sorting_algorithm = results_input_ord[is_sorting_algorithm]
        sorting_algorithm_mins = []
        for input_size in input_sizes:
            is_input_size = results_sorting_algorithm['Input size'] == input_size
            results_input_size = results_sorting_algorithm[is_input_size]
            sorting_algorithm_mins.append(np.amin(results_input_size['Time']))
        
        plt.loglog(input_sizes, sorting_algorithm_mins)
    
    plt.legend(['Merge sort', 'Heapsort', 'Quicksort', 'Built-in Python', 'Numpy'])
    plt.savefig(input_ord + '.png')

# %% [markdown]
# ## Plotting by sorting algorithm

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

results = pd.read_csv('results.csv')

x = [10**1, 10**2, 10**3, 10**4, 10**5, 10**6, 10**7]

plt.figure()
#plt.plot(np.log10(x), np.log10([(10**(-5))*n*np.log2(n) for n in x]), '--', color='k')
plt.plot(np.log10(x), np.log10([(10**(-6))*n*np.log2(n) for n in x]), '--', color='k')

#plt.plot(np.log10(x), np.log10([10**-5*n for n in x]), '--', color='k')

#plt.plot(np.log10(x), np.log10([10**-8*n**2 for n in x]), '--', color='k')
#plt.plot(np.log10(x), np.log10([10**-12*n**2 for n in x]), '--', color='k')
 
input_ord = 'random'
sorting_algorithm = 'Numpy'

is_input_ord = results['Input ordering'] == input_ord
results_input_ord = results[is_input_ord]

is_sorting_algorithm = results_input_ord['Sorting algorithm'] == sorting_algorithm
results_sorting_algorithm = results_input_ord[is_sorting_algorithm]
sorting_algorithm_means = []
for n in x:
    is_input_size = results_sorting_algorithm['Input size'] == n
    results_input_size = results_sorting_algorithm[is_input_size]
    sorting_algorithm_means.append(np.amin(results_input_size['Time']))
plt.plot(np.log10(x), np.log10(sorting_algorithm_means), 'o-', color='C4')

plt.title(sorting_algorithm + ': ' + input_ord + ' data')
plt.savefig(sorting_algorithm + '_' + input_ord + '.pdf')
plt.show()
